# %% [markdown]
# # Self-Consistency Prompting

# %%
import os
from langchain import PromptTemplate, LLMChain
from langchain_openai import ChatOpenAI

# %%
# Define the question
question = """A farmer has 20 apple trees. Each tree produces 10 apples per day. 
The farmer eats 4 apples himself and uses 6 apples to make pies every day. He sells the rest for $0.50 per apple. 
How much money does he make every day?"""

# %%
# Define the prompt template
prompt_template = """
Q: {question}
"""
# Create the prompt object
prompt = PromptTemplate(template=prompt_template, input_variables=["question"])

llm = ChatOpenAI(temperature=0, model_name="gpt-4o", openai_api_key=os.environ['OPENAI_API_KEY'])
llm_chain = LLMChain(prompt=prompt, llm=llm)

# %%
# Generate multiple reasoning paths
responses = []

for _ in range(5):  # Generate 5 different responses
   response = llm_chain.run(question=question)
   responses.append(response.strip())

# %%
# Aggregate the results and find the most consistent answer
from collections import Counter

# Extract final answers from the reasoning paths
final_answers = [resp for resp in responses]
most_common_answer = Counter(final_answers).most_common(1)[0][0]

# Display all responses and the most consistent answer
print("Responses:")
for i, resp in enumerate(responses, 1):
   print(f"Response {i}: {resp}")

print("\nMost Consistent Answer:", most_common_answer)
# Out:
# Responses:
# Response 1: To determine how much money the farmer makes every day, we need to calculate the total number of apples he sells daily and then multiply that by the price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    - The farmer has 20 apple trees.
#    - Each tree produces 10 apples per day.
#    - Total apples produced per day = 20 trees × 10 apples/tree = 200 apples.
#
# 2. **Calculate the number of apples the farmer consumes and uses:**
#    - The farmer eats 4 apples per day.
#    - The farmer uses 6 apples to make pies per day.
#    - Total apples consumed and used = 4 apples (eaten) + 6 apples (for pies) = 10 apples.
#
# 3. **Calculate the number of apples available for sale:**
#    - Apples available for sale = Total apples produced - Apples consumed and used
#    - Apples available for sale = 200 apples - 10 apples = 190 apples.
#
# 4. **Calculate the daily earnings from selling apples:**
#    - The farmer sells each apple for $0.50.
#    - Daily earnings = 190 apples × $0.50/apple = $95.
#
# Therefore, the farmer makes $95 every day from selling apples.
# Response 2: To determine how much money the farmer makes every day, we need to calculate the total number of apples he sells daily and then multiply that by the selling price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    - The farmer has 20 apple trees.
#    - Each tree produces 10 apples per day.
#    - Total apples produced per day = 20 trees × 10 apples/tree = 200 apples.
#
# 2. **Calculate the number of apples the farmer consumes and uses:**
#    - The farmer eats 4 apples per day.
#    - The farmer uses 6 apples to make pies per day.
#    - Total apples consumed and used = 4 apples + 6 apples = 10 apples.
#
# 3. **Calculate the number of apples available for sale:**
#    - Apples available for sale = Total apples produced - Apples consumed and used
#    - Apples available for sale = 200 apples - 10 apples = 190 apples.
#
# 4. **Calculate the daily earnings from selling apples:**
#    - The selling price is $0.50 per apple.
#    - Daily earnings = 190 apples × $0.50/apple = $95.
#
# Therefore, the farmer makes $95 every day from selling apples.
# Response 3: To determine how much money the farmer makes every day, we need to calculate the total number of apples he sells daily and then multiply that by the price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    - The farmer has 20 apple trees.
#    - Each tree produces 10 apples per day.
#    - Total apples produced per day = 20 trees × 10 apples/tree = 200 apples.
#
# 2. **Calculate the number of apples the farmer consumes and uses:**
#    - The farmer eats 4 apples per day.
#    - The farmer uses 6 apples to make pies per day.
#    - Total apples consumed and used = 4 apples + 6 apples = 10 apples.
#
# 3. **Calculate the number of apples available for sale:**
#    - Apples available for sale = Total apples produced - Apples consumed and used
#    - Apples available for sale = 200 apples - 10 apples = 190 apples.
#
# 4. **Calculate the daily earnings from selling apples:**
#    - The farmer sells each apple for $0.50.
#    - Daily earnings = 190 apples × $0.50/apple = $95.
#
# Therefore, the farmer makes $95 every day from selling apples.
# Response 4: To determine how much money the farmer makes every day, we need to calculate the number of apples he sells daily and then multiply that by the selling price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    \[
#    20 \text{ trees} \times 10 \text{ apples per tree} = 200 \text{ apples}
#    \]
#
# 2. **Calculate the number of apples the farmer consumes and uses for pies:**
#    - The farmer eats 4 apples.
#    - The farmer uses 6 apples to make pies.
#    \[
#    4 \text{ (eaten)} + 6 \text{ (for pies)} = 10 \text{ apples}
#    \]
#
# 3. **Calculate the number of apples available for sale:**
#    \[
#    200 \text{ (total apples)} - 10 \text{ (consumed and used for pies)} = 190 \text{ apples}
#    \]
#
# 4. **Calculate the daily earnings from selling apples:**
#    \[
#    190 \text{ apples} \times \$0.50 \text{ per apple} = \$95
#    \]
#
# Therefore, the farmer makes $95 every day from selling apples.
# Response 5: To determine how much money the farmer makes every day, we need to calculate the number of apples he sells and then multiply that by the price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    - The farmer has 20 apple trees.
#    - Each tree produces 10 apples per day.
#    - Total apples produced per day = 20 trees * 10 apples/tree = 200 apples.
#
# 2. **Calculate the number of apples the farmer uses daily:**
#    - The farmer eats 4 apples.
#    - The farmer uses 6 apples to make pies.
#    - Total apples used by the farmer = 4 (eaten) + 6 (pies) = 10 apples.
#
# 3. **Calculate the number of apples available for sale:**
#    - Apples available for sale = Total apples produced - Apples used by the farmer
#    - Apples available for sale = 200 apples - 10 apples = 190 apples.
#
# 4. **Calculate the daily earnings from selling apples:**
#    - The farmer sells each apple for $0.50.
#    - Daily earnings = 190 apples * $0.50/apple = $95.
#
# Therefore, the farmer makes $95 every day from selling apples.
#
# Most Consistent Answer: To determine how much money the farmer makes every day, we need to calculate the total number of apples he sells daily and then multiply that by the price per apple.
#
# 1. **Calculate the total number of apples produced daily:**
#    - The farmer has 20 apple trees.
#    - Each tree produces 10 apples per day.
#    - Total apples produced per day = 20 trees × 10 apples/tree = 200 apples.
#
# 2. **Calculate the number of apples the farmer consumes and uses:**
#    - The farmer eats 4 apples per day.
#    - The farmer uses 6 apples to make pies per day.
#    - Total apples consumed and used = 4 apples (eaten) + 6 apples (for pies) = 10 apples.
#
# 3. **Calculate the number of apples available for sale:**
#    - Apples available for sale = Total apples produced - Apples consumed and used
#    - Apples available for sale = 200 apples - 10 apples = 190 apples.
#
# 4. **Calculate the daily earnings from selling apples:**
#    - The farmer sells each apple for $0.50.
#    - Daily earnings = 190 apples × $0.50/apple = $95.
#
# Therefore, the farmer makes $95 every day from selling apples.
